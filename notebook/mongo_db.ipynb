# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://Usvisa:Raveenkumar@cluster0.q7ktbxf.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
iRGXk3HBiUB17MhZ

# %%
import pandas as pd  # type: ignore

# %%
df = pd.read_csv('Visadataset.csv')
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
records = df.to_dict(orient='records')

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
database_name = "us_visa"
collection_name = "US_VISA"

# %%
collection = client[database_name][collection_name]

# %%
collection.insert_many(documents=records, ordered=True)
# Out:
# InsertManyResult([ObjectId('66a8c8221e764315fb4da51f'), ObjectId('66a8c8221e764315fb4da520'), ObjectId('66a8c8221e764315fb4da521'), ObjectId('66a8c8221e764315fb4da522'), ObjectId('66a8c8221e764315fb4da523'), ObjectId('66a8c8221e764315fb4da524'), ObjectId('66a8c8221e764315fb4da525'), ObjectId('66a8c8221e764315fb4da526'), ObjectId('66a8c8221e764315fb4da527'), ObjectId('66a8c8221e764315fb4da528'), ObjectId('66a8c8221e764315fb4da529'), ObjectId('66a8c8221e764315fb4da52a'), ObjectId('66a8c8221e764315fb4da52b'), ObjectId('66a8c8221e764315fb4da52c'), ObjectId('66a8c8221e764315fb4da52d'), ObjectId('66a8c8221e764315fb4da52e'), ObjectId('66a8c8221e764315fb4da52f'), ObjectId('66a8c8221e764315fb4da530'), ObjectId('66a8c8221e764315fb4da531'), ObjectId('66a8c8221e764315fb4da532'), ObjectId('66a8c8221e764315fb4da533'), ObjectId('66a8c8221e764315fb4da534'), ObjectId('66a8c8221e764315fb4da535'), ObjectId('66a8c8221e764315fb4da536'), ObjectId('66a8c8221e764315fb4da537'), ObjectId('66a8c8221e764315fb4d
# ...

# %%
get_all_records = collection.find()

# %%
for record in get_all_records:
    print(record)
    break
# Out:
# {'_id': ObjectId('66a8c8221e764315fb4da51f'), 'case_id': 'EZYV01', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 14513, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 592.2029, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}

# %%
pd.DataFrame(records)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.DataFrame(list(records))
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
list(records)
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied',
#   '_id': ObjectId('66a8c8221e764315fb4da51f')},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified',
#   '_id': ObjectId('66a8c8221e764315fb4da520')},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
# ...

# %%
from from_root import from_root,from_here  # type: ignore

# %%
from_root('dir1','dir2','ap.py')
# Out:
# WindowsPath('E:/data science/Projects/US-VISA-APPROVAL-PREDICTION/dir1/dir2/ap.py')

# %%
from_here('dir1','dir2','ap.py')
# Out:
# WindowsPath('C:/Users/RAVEEN/AppData/Local/Temp/ipykernel_22872/dir1/dir2/ap.py')
